# %% [markdown]
# <a href="https://colab.research.google.com/github/Giandonn/Machine-Learning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

dt_brasil_argentina = dt[ (dt["team"] == "Brazil") &
  (dt["home_team"] == "Argentina") ]

dt_agrupado = dt_brasil_argentina.groupby("date")["scorer"].agg(', '.join).reset_index()

plt.figure(figsize=(25, 15))
plt.bar(dt_agrupado["date"], dt_agrupado["scorer"], color="green")
plt.xlabel("Ano")
plt.ylabel("Marcadores")
plt.title("Gols do Brasil na Argentina")
plt.xticks(dt_agrupado["date"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

neymar_gols = dt[(dt['scorer'] == "Neymar")]

dt_agrupado = neymar_gols.groupby("date")["scorer"].count().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(x="date", y="scorer", data=dt_agrupado, marker="o", linestyle="-", color="green")

plt.xlabel("Data")
plt.ylabel("Quantidade de Gols")
plt.title("Gols do Neymar ao longo dos anos")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

neymar_gols = dt[dt['scorer'] == "Neymar"]

dt_agrupado = neymar_gols.groupby("date")["scorer"].count().reset_index()

dt_agrupado.rename(columns={"scorer": "gols"}, inplace=True)

plt.figure(figsize=(10, 5))
sns.scatterplot(x="date", y="gols", data=dt_agrupado, color="green", s=100)

plt.xlabel("Data")
plt.ylabel("Quantidade de Gols")
plt.title("Gols de Neymar ao longo dos anos")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

# Renomeando as colunas
dt = dt.rename(columns={"date": "Data", "home_team": "Time da Casa", "away_team" : "Time de Fora", "team" : "Time", "scorer" : "Marcador", "minute" : "Minuto", "own_goal" : "Gol próprio", "penalty" : "Penalti"})
# Out:
# Index(['Data', 'Time da Casa', 'Time de Fora', 'Time', 'Marcador', 'Minuto',
#        'Gol próprio', 'Penalti'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

copia_dt = dt[dt["date"] > "2024-01-01"].copy()

print(copia_dt)
# Out:
#              date  home_team away_team       team            scorer  minute  \
# 43839  2024-01-12      Qatar   Lebanon      Qatar        Akram Afif    45.0
# 43840  2024-01-12      Qatar   Lebanon      Qatar        Almoez Ali    56.0
# 43841  2024-01-12      Qatar   Lebanon      Qatar        Akram Afif    90.0
# 43842  2024-01-13  Australia     India  Australia    Jackson Irvine    50.0
# 43843  2024-01-13  Australia     India  Australia        Jordan Bos    73.0
# ...           ...        ...       ...        ...               ...     ...
# 44357  2024-07-13     Canada   Uruguay    Uruguay       Luis Suárez    90.0
# 44358  2024-07-14  Argentina  Colombia  Argentina  Lautaro Martínez   112.0
# 44359  2024-07-14      Spain   England      Spain     Nico Williams    47.0
# 44360  2024-07-14      Spain   England    England       Cole Palmer    73.0
# 44361  2024-07-14      Spain   England      Spain   Mikel Oyarzabal    86.0
#
#        own_goal  penalty
# 43839     False    False
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

dt["Media_Movel_Minutos"] = dt["minute"].rolling(window=3, min_periods=1).mean()

print(dt["Media_Movel_Minutos"])
# Out:
# 0        44.000000
# 1        49.500000
# 2        56.333333
# 3        66.666667
# 4        49.000000
#            ...
# 44357    64.000000
# 44358    94.000000
# 44359    83.000000
# 44360    77.333333
# 44361    68.666667
# Name: Media_Movel_Minutos, Length: 44362, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

dt_original = dt.copy()

dt_filtrado = dt[ (dt['date'] >= "2024-01-01") & (dt['minute'] <= 45.0) & (dt['penalty'] == True) ]

print("dataset original:")
print(dt_original.describe())

print("dataset filtrado:")
print(dt_filtrado.describe())
# Out:
# dataset original:
#              minute
# count  44103.000000
# mean      50.012698
# std       26.358013
# min        1.000000
# 25%       28.000000
# 50%       51.000000
# 75%       73.000000
# max      122.000000
# dataset filtrado:
#           minute
# count  24.000000
# mean   27.750000
# std    13.712102
# min     6.000000
# 25%    15.000000
# 50%    28.500000
# 75%    42.750000
# max    45.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dt = pd.read_csv("/content/sample_data/goalscorers.csv")

dt["Media_Movel_Minutos"] = dt["minute"].rolling(window=3, min_periods=1).mean()

dt["Tempo"] = dt["minute"].apply(lambda x: "1º Tempo" if x <= 45 else "2º Tempo").dropna()

print(dt)
# Out:
#              date  home_team away_team       team            scorer  minute  \
# 0      1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1      1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2      1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3      1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4      1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
# ...           ...        ...       ...        ...               ...     ...
# 44357  2024-07-13     Canada   Uruguay    Uruguay       Luis Suárez    90.0
# 44358  2024-07-14  Argentina  Colombia  Argentina  Lautaro Martínez   112.0
# 44359  2024-07-14      Spain   England      Spain     Nico Williams    47.0
# 44360  2024-07-14      Spain   England    England       Cole Palmer    73.0
# 44361  2024-07-14      Spain   England      Spain   Mikel Oyarzabal    86.0
#
#        own_goal  penalty  Media_Movel_Minutos     Tempo
# ...
